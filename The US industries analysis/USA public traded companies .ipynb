# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_1 = pd.read_csv("USA public companies.csv")

# %%
file_2 = file_1.drop(["SEC Filings"], axis = 1)
file_2
# Out:
#     Symbol                    Name                  Sector   Price  \
# 0      MMM              3M Company             Industrials  222.89
# 1      AOS         A.O. Smith Corp             Industrials   60.24
# 2      ABT     Abbott Laboratories             Health Care   56.27
# 3     ABBV             AbbVie Inc.             Health Care  108.48
# 4      ACN           Accenture plc  Information Technology  150.51
# ..     ...                     ...                     ...     ...
# 500    XYL              Xylem Inc.             Industrials   70.24
# 501    YUM         Yum! Brands Inc  Consumer Discretionary   76.30
# 502    ZBH  Zimmer Biomet Holdings             Health Care  115.53
# 503   ZION           Zions Bancorp              Financials   50.71
# 504    ZTS                  Zoetis             Health Care   71.51
#
#      Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# 0             24.31        2.332862            7.92       259.77
# ...

# %%
frequency_file = file_2["Sector"].value_counts()

# %%
frequency_file.to_csv("frequency file.csv")

# %%
new_f_file = pd.read_csv("frequency file.csv")
new_f_file.rename(columns={ new_f_file.columns[0]: "Sectors", new_f_file.columns[1]: "Frequency"}, inplace = True)

# %%
new_f_file.to_csv("Sector freqeuncy file.csv")

# %%
sector_frequency = pd.read_csv("Sector freqeuncy file.csv")

# %%
sector_frequency.reset_index(drop = True, inplace = True)
sector_frequency
# Out:
#     Unnamed: 0                     Sectors  Frequency
# 0            0      Consumer Discretionary         84
# 1            1      Information Technology         70
# 2            2                  Financials         68
# 3            3                 Industrials         67
# 4            4                 Health Care         61
# 5            5            Consumer Staples         34
# 6            6                 Real Estate         33
# 7            7                      Energy         32
# 8            8                   Utilities         28
# 9            9                   Materials         25
# 10          10  Telecommunication Services          3

# %%
sector_frequency.drop("Unnamed: 0", axis = 1)
# Out:
#                        Sectors  Frequency
# 0       Consumer Discretionary         84
# 1       Information Technology         70
# 2                   Financials         68
# 3                  Industrials         67
# 4                  Health Care         61
# 5             Consumer Staples         34
# 6                  Real Estate         33
# 7                       Energy         32
# 8                    Utilities         28
# 9                    Materials         25
# 10  Telecommunication Services          3

# %%
plt.bar(sector_frequency["Sectors"].unique(), sector_frequency["Frequency"])

plt.xticks(sector_frequency["Sectors"].unique(), rotation = "vertical", size = "10")
plt.ylabel("Frequency")
plt.xlabel("Sectors")
plt.show()
